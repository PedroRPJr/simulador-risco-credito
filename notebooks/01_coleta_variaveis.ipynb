# %%
# Manipulação e análise de dados
import pandas as pd
import numpy as np

# Validação de dados
import pandera as pa
from pandera import Column, DataFrameSchema, Check

# Requisições e manipulação de arquivos
import requests
import zipfile
import os
import io
from pathlib import Path

# Utilitários
from functools import reduce

# %%
# -------------------------------
# Função para coletar dados do Banco Central (SGS)
# -------------------------------
def coleta_bcb(codigo, nome):
    url = f"https://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo}/dados?formato=json&dataInicial=01/01/2015&dataFinal=31/12/2024"
    r = requests.get(url)
    dados = pd.DataFrame(r.json())
    dados["data"] = pd.to_datetime(dados["data"], dayfirst=True)
    dados["valor"] = dados["valor"].astype(float)
    dados.rename(columns={"valor": nome}, inplace=True)
    return dados

# -------------------------------
# Coletar Inadimplências
# -------------------------------
inad_pj_tot = coleta_bcb(21083, "inad_pj_tot")                                          # Inadimplência da carteira de crédito das Pessoas Jurídicas_PJ _Total
inad_pf_tot = coleta_bcb(21084, "inad_pf_tot")                                          # Inadimplência da carteira de crédito das Pessoas Físicas_PF_Total
inad_rd_pf_cr_rur_tot = coleta_bcb(21148, "inad_rd_pf_cr_rur_tot")
inad_rd_pj_cr_rur_tot = coleta_bcb(21136, "inad_rd_pj_cr_rur_tot")

# Lista de Inadimplências:
lista_inad = [
    inad_pj_tot,
    inad_pf_tot,
    inad_rd_pf_cr_rur_tot,
    inad_rd_pj_cr_rur_tot
]

# Juntar em um único dataframe
df_inadimplencia = reduce(
    lambda left, right: pd.merge(left, right, on="data", how="outer"),
    lista_inad
)

# Ordenar por 'data'
df_inadimplencia = df_inadimplencia.sort_values("data").reset_index(drop=True)
df_inadimplencia["data"] = df_inadimplencia["data"].dt.strftime("%m/%Y")

# %%
# -------------------------------
# Coletar outras variáveis
# -------------------------------
selic = coleta_bcb(11, "selic")                                 # Taxa Selic
ipca = coleta_bcb(4449, "ipca")                                 # Inflação IPCA
cdi = coleta_bcb(12, "cdi")                                     # CDI (média diária)
spread_pf = coleta_bcb(20785, "spread_pf")                      # Spread bancário PF
spread_pj = coleta_bcb(20784, "spread_pj")                      # Spread bancário PJ
spread_tot = coleta_bcb(20783, "spread_tot")                    # Spread bancário total
dolar = coleta_bcb(1, "dolar_ptax")                             # Taxa de câmbio - Livre - Dólar americano (venda)
icms_petroleo = coleta_bcb(7694, "icms_petroleo")               # Arrecadação de ICMS (Fluxos) - Petróleo - Total Nacional 
soja_triturada_expt = coleta_bcb(2971, "soja_triturada_expt")   # Exportações - Soja mesmo triturada _ US$
soja_residuo_expt = coleta_bcb(2959, "soja_residuo_expt")       # Exportações - Farelo e resíduos da extração de óleo de soja _ US$
soja_oleo_expt = coleta_bcb(2959, "soja_oleo_expt")             # Exportações - Óleo de soja em bruto _ US$
milho_grao_expt = coleta_bcb(20213, "milho_grao_expt")          # Exportações - Milhos em grãos _ US$


# Lista de Variáveis Econômicas_periodicidade mensal:
lista_var_econ_mensal = [
    ipca,
    spread_pf,
    spread_pj,
    spread_tot,
    icms_petroleo,
    soja_triturada_expt,
    soja_residuo_expt,
    soja_oleo_expt,
    milho_grao_expt
]

# Lista de Variáveis Econômicas_periodicidade diária:
lista_var_econ_diaria = [
    selic,
    cdi,
    dolar
]

# Juntar variáveis mensais:
df_econ_mensal = reduce(
    lambda left, right: pd.merge(left, right, on="data", how="outer"),
    lista_var_econ_mensal
)

# Juntar variáveis diárias:
df_econ_diaria = reduce(
    lambda left, right: pd.merge(left, right, on="data", how="outer"),
    lista_var_econ_diaria
)

# Converter datas:
df_econ_mensal["data"] = pd.to_datetime(df_econ_mensal["data"])
df_econ_mensal["data"] = df_econ_mensal["data"].dt.strftime("%m/%Y")
df_econ_diaria["data"] = pd.to_datetime(df_econ_diaria["data"])

# Transformar diárias em mensais (média mensal):
df_econ_diaria = df_econ_diaria.resample("ME", on="data").mean().reset_index()
df_econ_diaria["data"] = df_econ_diaria["data"].dt.strftime("%m/%Y")

# Juntar em um único dataframe:
df_economico = pd.merge(df_econ_mensal, df_econ_diaria, on="data", how="outer")
df_economico = df_economico.sort_values("data").reset_index(drop=True)

# %%
# -------------------------------
# Cletar dados do IBGE (SIDRA)
# -------------------------------

# URL da API para Rendimento médio real habitual da população ocupada (PNAD Contínua)
url_renda = "https://apisidra.ibge.gov.br/values/t/7437/n1/all/v/10750/p/last%2010/c11308/49204"

# Fazendo a requisição e conversão
response_renda = requests.get(url_renda)
dados_renda = response_renda.json()

# Transformando em DataFrame
df_renda = pd.DataFrame(dados_renda)

# Exclusão das variáveis desnecessárias e renomear as variáveis úteis
df_renda = df_renda.iloc[1:].reset_index(drop=True)
df_renda = df_renda[["D2C", "D3C", "MN", "V"]]
df_renda.rename(columns={
    "D2C": "variavel",
    "D3C": "data",
    "MN": "unid_medida",
    "V": "valor"
    }, inplace=True)

# limpar valores inválidos
df_renda["valor"] = (
    df_renda["valor"]
    .replace(["...", "", "nan", "NaN", None, pd.NA], np.nan)
    .astype(float)
)

lista_nomes_variaveis_renda = {
    "10750": "rendimento_medio_mensal_reais"
}

# Renda anual → expandir para meses
df_renda["data"] = pd.to_datetime(df_renda["data"], format="%Y")
df_renda = df_renda.pivot_table(index="data", columns="variavel", values="valor", aggfunc="mean").reset_index()

# Renomear colunas usando o dicionário
df_renda.rename(columns=lista_nomes_variaveis_renda, inplace=True)

df_renda_mensal = df_renda.set_index("data").resample("ME").ffill().reset_index()
df_renda_mensal["data"] = df_renda_mensal["data"].dt.strftime("%m/%Y")



# URL da API para dados de Trabalho do IBGE
url_trabalho = f"https://apisidra.ibge.gov.br/values/t/4093/n1/all/v/1641,4088,4090,4092,4094,4096,4099,12466/p/all"

response_trabalho = requests.get(url_trabalho)
dados_trabalho = response_trabalho.json()

# Transformando em DataFrame
df_trabalho = pd.DataFrame(dados_trabalho)

# Exclusão das variáveis desnecessárias e renomear as variáveis úteis
df_trabalho = df_trabalho.iloc[1:].reset_index(drop=True)
df_trabalho = df_trabalho[["D2C", "D3C", "MN", "V"]]
df_trabalho.rename(columns={
    "D2C": "variavel",
    "D3C": "data",
    "MN": "unid_medida",
    "V": "valor"
    }, inplace=True)

def converte_trimestre(valor):
    valor = str(valor)
    # garante que tem 6 dígitos (AAAA + TT)
    if len(valor) != 6 or not valor.isdigit():
        return pd.NaT
    ano = int(valor[:4])
    trimestre = int(valor[4:])
    # trimestre → mês inicial
    mes = {1: 1, 2: 4, 3: 7, 4: 10}.get(trimestre)
    # se trimestre for inválido
    if mes is None:
        return pd.NaT
    return pd.Timestamp(year=ano, month=mes, day=1)


# limpar valores inválidos
df_trabalho["data"] = df_trabalho["data"].replace(["...", "", "nan", None, pd.NA], np.nan)
df_trabalho = df_trabalho[df_trabalho["data"].str.match(r"^\d{6}$", na=False)]

# Limpar a coluna 'valor'
df_trabalho["valor"] = (
    df_trabalho["valor"]
    .replace(["...", "", "nan", "NaN", None, pd.NA], np.nan)
    .astype(float)
)

# Converter trimestre
df_trabalho["data"] = df_trabalho["data"].apply(converte_trimestre)

# Pivotar ANTES do resample
df_trabalho = df_trabalho.pivot_table(index="data", columns="variavel", values="valor", aggfunc="mean").reset_index()

lista_nomes_variaveis_trabalho = {
    "1641": "pessoas_14mais_mil",
    "4088": "p14m_forca_trabalho_mil",
    "4090": "p14m_ocupadas_mil",
    "4092": "p14m_desocupadas_mil",
    "4094": "p14m_fora_forca_trabalho_mil",
    "4096": "tx_foca_trabalho_p14m_pct",
    "4099": "tx_desocupacao_p14m_pct",
    "12466": "tx_informalidade_p14m_ocupadas_pct"
}

# Renomear colunas
df_trabalho.rename(columns=lista_nomes_variaveis_trabalho, inplace=True)

# expandir para meses
df_trabalho_mensal = (df_trabalho.set_index("data").resample("ME").ffill().reset_index())
df_trabalho_mensal["data"] = df_trabalho_mensal["data"].dt.strftime("%m/%Y")

# Juntar em um único dataframe:
df_ibge = pd.merge(df_renda_mensal, df_trabalho_mensal, on="data", how="outer")
df_ibge = df_ibge.sort_values("data").reset_index(drop=True)

# %%
# Dicionário com nome → dataframe
dfs_para_salvar = {
    "inadimplencia": df_inadimplencia,
    "economico": df_economico,
    "ibge": df_ibge
}

# Loop para salvar todos
for nome, df in dfs_para_salvar.items():
    caminho = f"../data/raw/df_{nome}.csv"
    df.to_csv(caminho, index=False)
    print(f"Salvo: {caminho}")
# Out:
# Salvo: ../data/raw/df_inadimplencia.csv
# Salvo: ../data/raw/df_economico.csv
# Salvo: ../data/raw/df_ibge.csv

# %%
# -------------------------------
# Cletar dados do INMET
# -------------------------------

zip_path = "C:/Users/pedro/projeto_inadimplencia/data/raw/INPE.zip"

dfs = []

with zipfile.ZipFile(zip_path, 'r') as z:
    arquivos = [f for f in z.namelist() if f.lower().endswith(".csv")]

    print(f"Total de arquivos CSV encontrados: {len(arquivos)}")

    for i, arquivo in enumerate(arquivos, start=1):
        print(f"Lendo arquivo {i}/{len(arquivos)}: {arquivo}")

        with z.open(arquivo) as f:
            # Ler o arquivo inteiro como texto
            conteudo = f.read().decode("latin1")  # encoding típico do INMET

            # Quebrar em linhas
            linhas = conteudo.splitlines()

            # Encontrar a linha onde começa a tabela (a que contém "Data Medicao")
            inicio_tabela = None
            for idx, linha in enumerate(linhas):
                if "Data Medicao" in linha:
                    inicio_tabela = idx
                    break

            if inicio_tabela is None:
                print(f"⚠ Não encontrei tabela em {arquivo}")
                continue

            # Extrair apenas a parte tabular
            tabela = "\n".join(linhas[inicio_tabela:])

            # Ler a tabela com pandas
            df = pd.read_csv(
                io.StringIO(tabela),
                sep=";",              # separador é ;
                decimal=",",           # vírgula decimal
                encoding="latin1"
            )

            df["arquivo_origem"] = arquivo
            dfs.append(df)

# Concatenar tudo
df_inmet = pd.concat(dfs, ignore_index=True)
# Out:
# Total de arquivos CSV encontrados: 322
# Lendo arquivo 1/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82704_M_2014-01-01_2016-01-29.csv
# Lendo arquivo 2/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82915_M_2014-01-01_2023-08-14.csv
# Lendo arquivo 3/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82807_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 4/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82113_M_2014-01-01_2025-04-24.csv
# Lendo arquivo 5/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82410_M_2014-01-01_2025-04-27.csv
# Lendo arquivo 6/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82425_M_2014-01-01_2016-01-29.csv
# Lendo arquivo 7/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82326_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 8/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82610_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 9/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82047_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 10/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82212_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 11/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82067_M_2014-01-01_2019-08-31.csv
# Lendo arquivo 12/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82336_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 13/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82723_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 14/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82331_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 15/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82533_M_2014-01-01_2022-06-20.csv
# Lendo arquivo 16/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82240_M_2014-01-01_2016-01-29.csv
# Lendo arquivo 17/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82106_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 18/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82317_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 19/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82029_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 20/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82098_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 21/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82353_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 22/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82191_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 23/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82246_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 24/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82188_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 25/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82263_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 26/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82861_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 27/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82445_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 28/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82562_M_2014-01-01_2025-07-03.csv
# Lendo arquivo 29/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82181_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 30/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82178_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 31/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82184_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 32/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82668_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 33/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82141_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 34/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82145_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 35/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82361_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 36/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82024_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 37/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82042_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 38/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82659_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 39/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83160_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 40/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83033_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 41/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82863_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 42/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83228_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 43/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83064_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 44/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83235_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 45/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82989_M_2014-01-01_2023-02-21.csv
# Lendo arquivo 46/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82995_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 47/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82994_M_2014-01-01_2021-04-07.csv
# Lendo arquivo 48/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82991_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 49/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82988_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 50/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82992_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 51/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82990_M_2014-01-01_2025-04-24.csv
# Lendo arquivo 52/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82998_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 53/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82996_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 54/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83249_M_2014-01-01_2022-01-14.csv
# Lendo arquivo 55/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83179_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 56/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83236_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 57/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83288_M_2014-01-01_2025-04-24.csv
# Lendo arquivo 58/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83339_M_2014-01-01_2019-07-31.csv
# Lendo arquivo 59/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83398_M_2014-01-01_2021-07-30.csv
# Lendo arquivo 60/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83498_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 61/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83408_M_2014-01-01_2020-10-31.csv
# Lendo arquivo 62/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83192_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 63/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83286_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 64/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83222_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 65/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83221_M_2014-01-01_2018-12-17.csv
# Lendo arquivo 66/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83446_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 67/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83182_M_2014-01-01_2021-07-30.csv
# Lendo arquivo 68/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83244_M_2014-01-01_2019-02-28.csv
# Lendo arquivo 69/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83347_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 70/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83295_M_2014-01-01_2016-01-30.csv
# Lendo arquivo 71/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83292_M_2014-01-01_2021-07-30.csv
# Lendo arquivo 72/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83186_M_2014-01-01_2023-03-02.csv
# Lendo arquivo 73/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83242_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 74/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83090_M_2014-01-01_2020-04-30.csv
# Lendo arquivo 75/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83184_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 76/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83549_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 77/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82986_M_2014-01-01_2015-04-30.csv
# Lendo arquivo 78/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82979_M_2014-01-01_2021-07-30.csv
# Lendo arquivo 79/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83229_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 80/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83190_M_2014-01-01_2024-06-05.csv
# Lendo arquivo 81/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83076_M_2014-01-01_2021-12-31.csv
# Lendo arquivo 82/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83344_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 83/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82784_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 84/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82777_M_2014-01-01_2019-03-31.csv
# Lendo arquivo 85/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82583_M_2014-01-01_2018-04-29.csv
# Lendo arquivo 86/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82397_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 87/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82487_M_2014-01-01_2019-08-30.csv
# Lendo arquivo 88/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82686_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 89/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82493_M_2014-01-01_2019-04-30.csv
# Lendo arquivo 90/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82785_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 91/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82588_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 92/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82486_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 93/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82586_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 94/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82392_M_2014-01-01_2020-08-30.csv
# Lendo arquivo 95/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82683_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 96/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82390_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 97/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82970_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 98/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82460_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 99/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82768_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 100/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82571_M_2014-01-01_2024-11-30.csv
# Lendo arquivo 101/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82765_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 102/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82476_M_2014-01-01_2022-08-30.csv
# Lendo arquivo 103/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82382_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 104/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82676_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 105/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82564_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 106/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82280_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 107/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82198_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 108/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82376_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 109/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82696_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 110/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82795_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 111/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82697_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 112/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82798_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 113/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82792_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 114/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82791_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 115/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82689_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 116/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82890_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 117/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82886_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 118/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82893_M_2014-01-01_2022-11-11.csv
# Lendo arquivo 119/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82799_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 120/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82781_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 121/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82898_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 122/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82753_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 123/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82892_M_2014-01-01_2015-11-18.csv
# Lendo arquivo 124/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82983_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 125/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82900_M_2014-01-01_2020-08-31.csv
# Lendo arquivo 126/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82797_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 127/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82897_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 128/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82789_M_2014-01-01_2018-03-28.csv
# Lendo arquivo 129/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82605_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 130/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82975_M_2014-01-01_2023-07-30.csv
# Lendo arquivo 131/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82474_M_2014-01-01_2015-02-26.csv
# Lendo arquivo 132/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82976_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 133/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82298_M_2014-01-01_2018-11-19.csv
# Lendo arquivo 134/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82678_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 135/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82296_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 136/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82684_M_2014-01-01_2015-02-24.csv
# Lendo arquivo 137/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82287_M_2014-01-01_2018-09-30.csv
# Lendo arquivo 138/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82882_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 139/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82780_M_2014-01-01_2022-10-03.csv
# Lendo arquivo 140/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82480_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 141/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82879_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 142/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82578_M_2014-01-01_2025-04-24.csv
# Lendo arquivo 143/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82870_M_2014-01-01_2018-06-30.csv
# Lendo arquivo 144/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82590_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 145/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82596_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 146/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82693_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 147/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82691_M_2014-01-01_2018-05-31.csv
# Lendo arquivo 148/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82597_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 149/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82594_M_2014-01-01_2018-07-31.csv
# Lendo arquivo 150/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82598_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 151/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82698_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 152/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_82690_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 153/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83096_M_2014-01-01_2020-12-31.csv
# Lendo arquivo 154/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83195_M_2014-01-01_2023-05-14.csv
# Lendo arquivo 155/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83097_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 156/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83841_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 157/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83839_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 158/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83783_M_2014-01-01_2016-12-21.csv
# Lendo arquivo 159/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83813_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 160/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83661_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 161/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83842_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 162/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83836_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 163/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83811_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 164/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83041_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 165/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83766_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 166/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83767_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 167/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83844_M_2014-01-01_2021-08-25.csv
# Lendo arquivo 168/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83917_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 169/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83980_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 170/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83994_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 171/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83919_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 172/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83946_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 173/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83942_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 174/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83912_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 175/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83964_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 176/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83881_M_2014-01-01_2018-07-31.csv
# Lendo arquivo 177/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83916_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 178/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83914_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 179/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83985_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 180/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83967_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 181/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83892_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 182/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83995_M_2014-01-01_2015-01-18.csv
# Lendo arquivo 183/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83936_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 184/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83997_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 185/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83907_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 186/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83948_M_2014-01-01_2021-04-26.csv
# Lendo arquivo 187/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83879_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 188/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83927_M_2014-01-01_2019-03-31.csv
# Lendo arquivo 189/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83893_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 190/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83887_M_2014-01-01_2017-07-31.csv
# Lendo arquivo 191/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83883_M_2014-01-01_2017-01-30.csv
# Lendo arquivo 192/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83897_M_2014-01-01_2020-03-01.csv
# Lendo arquivo 193/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83872_M_2014-01-01_2018-03-30.csv
# Lendo arquivo 194/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83891_M_2014-01-01_2017-04-02.csv
# Lendo arquivo 195/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83920_M_2014-01-01_2017-05-30.csv
# Lendo arquivo 196/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83923_M_2014-01-01_2017-09-29.csv
# Lendo arquivo 197/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83557_M_2014-01-01_2023-09-28.csv
# Lendo arquivo 198/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83546_M_2014-01-01_2015-02-27.csv
# Lendo arquivo 199/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83596_M_2014-01-01_2016-05-31.csv
# Lendo arquivo 200/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83013_M_2014-01-01_2024-04-27.csv
# Lendo arquivo 201/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83550_M_2014-01-01_2021-07-23.csv
# Lendo arquivo 202/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83648_M_2014-01-01_2024-08-19.csv
# Lendo arquivo 203/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83595_M_2014-01-01_2014-07-15.csv
# Lendo arquivo 204/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83442_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 205/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83579_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 206/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83384_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 207/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83582_M_2014-01-01_2018-04-04.csv
# Lendo arquivo 208/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83689_M_2014-01-01_2018-05-30.csv
# Lendo arquivo 209/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83587_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 210/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83533_M_2014-01-01_2019-01-31.csv
# Lendo arquivo 211/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83589_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 212/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83681_M_2014-01-01_2015-09-16.csv
# Lendo arquivo 213/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83639_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 214/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83514_M_2014-01-01_2018-08-13.csv
# Lendo arquivo 215/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83592_M_2014-01-01_2024-11-29.csv
# Lendo arquivo 216/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83485_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 217/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83536_M_2014-01-01_2022-04-30.csv
# Lendo arquivo 218/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83538_M_2014-01-01_2020-02-29.csv
# Lendo arquivo 219/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83635_M_2014-01-01_2021-09-02.csv
# Lendo arquivo 220/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83338_M_2014-01-01_2019-03-14.csv
# Lendo arquivo 221/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83581_M_2014-01-01_2018-07-04.csv
# Lendo arquivo 222/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83334_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 223/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83632_M_2014-01-01_2021-11-29.csv
# Lendo arquivo 224/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83390_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 225/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83488_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 226/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83521_M_2014-01-01_2015-10-25.csv
# Lendo arquivo 227/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83395_M_2014-01-01_2016-08-30.csv
# Lendo arquivo 228/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83386_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 229/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83591_M_2014-01-01_2019-05-31.csv
# Lendo arquivo 230/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83481_M_2014-01-01_2018-01-31.csv
# Lendo arquivo 231/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83692_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 232/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83452_M_2014-01-01_2024-02-29.csv
# Lendo arquivo 233/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83687_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 234/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83683_M_2014-01-01_2022-05-31.csv
# Lendo arquivo 235/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83015_M_2014-01-01_2016-08-30.csv
# Lendo arquivo 236/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83578_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 237/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83388_M_2014-01-01_2016-01-31.csv
# Lendo arquivo 238/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83437_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 239/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83501_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 240/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83637_M_2014-01-01_2017-10-18.csv
# Lendo arquivo 241/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83479_M_2014-01-01_2021-11-22.csv
# Lendo arquivo 242/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83737_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 243/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83531_M_2014-01-01_2018-05-30.csv
# Lendo arquivo 244/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83393_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 245/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83483_M_2014-01-01_2019-10-01.csv
# Lendo arquivo 246/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83570_M_2014-01-01_2015-12-30.csv
# Lendo arquivo 247/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83387_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 248/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83441_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 249/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83736_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 250/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83631_M_2014-01-01_2014-03-11.csv
# Lendo arquivo 251/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83586_M_2014-01-01_2016-07-20.csv
# Lendo arquivo 252/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83492_M_2014-01-01_2019-03-11.csv
# Lendo arquivo 253/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83577_M_2014-01-01_2018-08-30.csv
# Lendo arquivo 254/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83428_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 255/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83642_M_2014-01-01_2018-03-07.csv
# Lendo arquivo 256/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83007_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 257/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83788_M_2014-01-01_2017-04-30.csv
# Lendo arquivo 258/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83049_M_2014-01-01_2020-02-29.csv
# Lendo arquivo 259/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83698_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 260/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83807_M_2014-01-01_2019-03-31.csv
# Lendo arquivo 261/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83718_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 262/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83114_M_2014-01-01_2024-04-10.csv
# Lendo arquivo 263/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83695_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 264/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83089_M_2014-01-01_2018-05-31.csv
# Lendo arquivo 265/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83801_M_2014-01-01_2022-05-31.csv
# Lendo arquivo 266/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83738_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 267/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83048_M_2014-01-01_2019-05-05.csv
# Lendo arquivo 268/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83743_M_2014-01-01_2017-04-04.csv
# Lendo arquivo 269/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83789_M_2014-01-01_2019-12-18.csv
# Lendo arquivo 270/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83696_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 271/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83805_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 272/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83744_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 273/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83773_M_2014-01-01_2014-01-31.csv
# Lendo arquivo 274/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83714_M_2014-01-01_2019-03-19.csv
# Lendo arquivo 275/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83676_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 276/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83823_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 277/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83630_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 278/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83075_M_2014-01-01_2014-12-08.csv
# Lendo arquivo 279/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83084_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 280/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83726_M_2014-01-01_2024-06-30.csv
# Lendo arquivo 281/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83713_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 282/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83781_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 283/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83669_M_2014-01-01_2024-11-30.csv
# Lendo arquivo 284/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83851_M_2014-01-01_2024-05-17.csv
# Lendo arquivo 285/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83651_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 286/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83784_M_2014-01-01_2014-08-10.csv
# Lendo arquivo 287/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83035_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 288/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83623_M_2014-01-01_2021-07-24.csv
# Lendo arquivo 289/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83377_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 290/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83373_M_2014-01-01_2017-09-30.csv
# Lendo arquivo 291/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83368_M_2014-01-01_2025-07-02.csv
# Lendo arquivo 292/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83526_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 293/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83379_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 294/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83423_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 295/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83374_M_2014-01-01_2017-10-02.csv
# Lendo arquivo 296/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83522_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 297/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83464_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 298/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83427_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 299/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83473_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 300/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83376_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 301/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83257_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 302/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83332_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 303/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83470_M_2014-01-01_2025-06-26.csv
# Lendo arquivo 304/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83701_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 305/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83552_M_2014-01-01_2014-06-30.csv
# Lendo arquivo 306/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83704_M_2014-01-01_2014-06-30.csv
# Lendo arquivo 307/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83513_M_2014-01-01_2019-11-30.csv
# Lendo arquivo 308/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83565_M_2014-01-01_2025-07-01.csv
# Lendo arquivo 309/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83702_M_2014-01-01_2016-01-31.csv
# Lendo arquivo 310/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83405_M_2014-01-01_2014-07-02.csv
# Lendo arquivo 311/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83270_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 312/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83265_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 313/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83361_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 314/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83309_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 315/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83264_M_2014-01-01_2014-05-01.csv
# Lendo arquivo 316/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83214_M_2014-01-01_2021-03-14.csv
# Lendo arquivo 317/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83319_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 318/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83364_M_2014-01-01_2025-12-26.csv
# Lendo arquivo 319/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83358_M_2014-01-01_2021-07-31.csv
# Lendo arquivo 320/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83410_M_2014-01-01_2016-01-28.csv
# Lendo arquivo 321/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83267_M_2014-01-01_2016-01-29.csv
# Lendo arquivo 322/322: $2a$10$iB76aNQvei789VcEXoSH.94OovXJv3GWpaZFK7vBSt2h3mIIbT6/dados_83363_M_2014-01-01_2025-02-27.csv

# %%
# Renomear colunas
rename_map = {
    "Data Medicao": "data",
    "INSOLACAO TOTAL, MENSAL(h)": "insolacao_total_h",
    "PRECIPITACAO TOTAL, MENSAL(mm)": "precipitacao_total_mm",
    "TEMPERATURA MAXIMA MEDIA, MENSAL(Â°C)": "temp_max_media_c",
    "TEMPERATURA MINIMA MEDIA, MENSAL(Â°C)": "temp_min_media_c",
    "UMIDADE RELATIVA DO AR, MEDIA MENSAL(%)": "umidade_media_pct",
    "VENTO, VELOCIDADE MAXIMA MENSAL(m/s)": "vento_vel_max_ms",
    "VENTO, VELOCIDADE MEDIA MENSAL(m/s)": "vento_vel_media_ms"
}

df_inmet = df_inmet.rename(columns=rename_map)

# Remover colunas indesejáveis
df_inmet = df_inmet.drop(columns=[
    "NEBULOSIDADE, MEDIA MENSAL(dÃ©cimos)",
    "Unnamed: 9",
    "arquivo_origem",
    "Unnamed: 1"
], errors="ignore")

# Converter data
df_inmet["data"] = pd.to_datetime(df_inmet["data"], errors="coerce")
df_inmet["data"] = df_inmet["data"].dt.strftime("%m/%Y")

# Juntar os dados como média mensal
df_mensal = df_inmet.groupby("data", as_index=False).mean(numeric_only=True).round(2)
df_inmet = df_mensal.sort_values("data").reset_index(drop=True)

# %%
# Salvar
output_path = "C:/Users/pedro/projeto_inadimplencia/data/raw/df_inmet.csv"
os.makedirs("C:/Users/pedro/projeto_inadimplencia/data/raw/", exist_ok=True)
df_inmet.to_csv(output_path, index=False, encoding="utf-8")

print(f"\nArquivo final salvo em: {output_path}")
# Out:
# Arquivo final salvo em: C:/Users/pedro/projeto_inadimplencia/data/raw/df_inmet.csv

# %%
# Configurações
BASE_PATH = Path("C:/Users/pedro/projeto_inadimplencia/data/raw")
BASE_PATH.mkdir(parents=True, exist_ok=True)

def criar_dataset_eventos(data_inicio="2015-01-01", data_fim="2024-12-31"):
    print("--- Gerando Dataset de Eventos Políticos ---")
    
    # 1. Criar range de datas mensal
    dates = pd.date_range(start=data_inicio, end=data_fim, freq="MS") # MS = Month Start
    df = pd.DataFrame({"data": dates})
    
    # 2. Inicializar Flags (0 para tudo)
    df["flag_pandemia"] = 0
    df["flag_greve_caminhoneiros"] = 0
    df["flag_eleicao_presidencial"] = 0
    df["flag_joesley_day"] = 0
    df["flag_impeachment"] = 0
    
    # 3. Definir Períodos Presidenciais (Categorical)
    # Útil para agrupar análises: "Qual foi a média de inadimplência no Gov Temer?"
    df["presidente"] = "Indefinido"
    
    mask_dilma = (df["data"] < "2016-09-01")
    mask_temer = (df["data"] >= "2016-09-01") & (df["data"] < "2019-01-01")
    mask_bolsonaro = (df["data"] >= "2019-01-01") & (df["data"] < "2023-01-01")
    mask_lula3 = (df["data"] >= "2023-01-01")
    
    df.loc[mask_dilma, "presidente"] = "Dilma"
    df.loc[mask_temer, "presidente"] = "Temer"
    df.loc[mask_bolsonaro, "presidente"] = "Bolsonaro"
    df.loc[mask_lula3, "presidente"] = "Lula"

    # 4. Mapear Eventos de Choque (Dummies)
    
    # Pandemia (OMS declara em Mar/2020 - Fim da emergência no BR em Mai/2022)
    # Impacto econômico severo
    df.loc[(df["data"] >= "2020-03-01") & (df["data"] <= "2022-05-01"), "flag_pandemia"] = 1
    
    # Greve dos Caminhoneiros (Maio de 2018)
    # Parou o país e gerou inflação imediata
    df.loc[df["data"] == "2018-05-01", "flag_greve_caminhoneiros"] = 1
    
    # Joesley Day (Maio de 2017)
    # Circuit Breaker na bolsa, disparada do dólar
    df.loc[df["data"] == "2017-05-01", "flag_joesley_day"] = 1
    
    # Processo de Impeachment (Acolhimento Dez/15 até Afastamento definitivo Ago/16)
    # Incerteza política extrema
    df.loc[(df["data"] >= "2015-12-01") & (df["data"] <= "2016-08-01"), "flag_impeachment"] = 1

    # Eleições Presidenciais (Mês do 1º e 2º turno - Outubro)
    # Volatilidade de mercado
    anos_eleitorais = ["2018-10-01", "2022-10-01"]
    df.loc[df["data"].isin(anos_eleitorais), "flag_eleicao_presidencial"] = 1

    return df

# ==============================================================================
# VALIDAÇÃO (PANDERA)
# ==============================================================================
def validar_e_salvar_eventos(df):
    # Schema: Garante que as flags sejam binárias (0 ou 1) e data esteja ok
    schema = DataFrameSchema({
        "data": Column(pd.Timestamp),
        "presidente": Column(str, checks=pa.Check.isin(["Dilma", "Temer", "Bolsonaro", "Lula"])),
        "flag_pandemia": Column(int, checks=pa.Check.isin([0, 1])),
        "flag_greve_caminhoneiros": Column(int, checks=pa.Check.isin([0, 1])),
        "flag_eleicao_presidencial": Column(int, checks=pa.Check.isin([0, 1])),
        "flag_impeachment": Column(int, checks=pa.Check.isin([0, 1])),
    }, strict=False) # strict=False aceita colunas extras se houver

    try:
        schema.validate(df)
        
        # Formatação final para CSV (String MM/YYYY) igual aos outros datasets
        df_save = df.copy()
        df_save["data"] = df_save["data"].dt.strftime("%m/%Y")
        
        caminho = BASE_PATH / "df_eventos_politicos.csv"
        df_save.to_csv(caminho, index=False, encoding="utf-8")
        print(f"✅ Sucesso! Arquivo salvo em: {caminho}")
        
    except pa.errors.SchemaErrors as err:
        print("❌ Erro na validação dos eventos:")
        print(err.failure_cases)

# ==============================================================================
# EXECUÇÃO
# ==============================================================================
if __name__ == "__main__":
    df_eventos = criar_dataset_eventos()
    validar_e_salvar_eventos(df_eventos)
# Out:
# --- Gerando Dataset de Eventos Políticos ---
# ✅ Sucesso! Arquivo salvo em: C:\Users\pedro\projeto_inadimplencia\data\raw\df_eventos_politicos.csv
# C:\Users\pedro\AppData\Local\Temp\ipykernel_10644\3280110537.py:54: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df.loc[df["data"].isin(anos_eleitorais), "flag_eleicao_presidencial"] = 1
# c:\Users\pedro\projeto_inadimplencia\venv\Lib\site-packages\pandera\_pandas_deprecated.py:146: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)
